# %%
# !pip3 install autokeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autokeras
#   Downloading autokeras-1.0.20-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 6.7 MB/s
# Collecting keras-tuner>=1.1.0
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 45.9 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from autokeras) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from autokeras) (21.3)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from autokeras) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.1.0->autokeras) (1.21.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.1.0->autokeras) (7.9.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.23.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.48.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.14.1)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (14.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (57.4.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (4.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (3.17.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.1.2)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (2.0.7)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (0.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (3.3.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (0.5.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->autokeras) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->autokeras) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.8.0->autokeras) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.1.0->autokeras) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner>=1.1.0->autokeras) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner>=1.1.0->autokeras) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.1.0->autokeras) (3.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (5.1.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 46.1 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->keras-tuner>=1.1.0->autokeras) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner>=1.1.0->autokeras) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->autokeras) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->autokeras) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->autokeras) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner>=1.1.0->autokeras) (0.7.0)
# Installing collected packages: jedi, kt-legacy, keras-tuner, autokeras
# Successfully installed autokeras-1.0.20 jedi-0.18.1 keras-tuner-1.1.3 kt-legacy-1.0.4

# %%
from pprint import pprint

import sklearn.datasets
import sklearn.metrics
import pandas as pd
import numpy as np

import autokeras as ak

# %% [markdown]
# LOADING *DATA*

# %%
TrainDataSet= pd.read_csv('../content/milknew.csv')
TrainDataSet.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %% [markdown]
# Data analysis

# %%
TrainDataSet.describe()
# Out:
#                 pH   Temprature        Taste         Odor         Fat   \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean      6.630123    44.226629     0.546742     0.432483     0.671388
# std       1.399679    10.098364     0.498046     0.495655     0.469930
# min       3.000000    34.000000     0.000000     0.000000     0.000000
# 25%       6.500000    38.000000     0.000000     0.000000     0.000000
# 50%       6.700000    41.000000     1.000000     0.000000     1.000000
# 75%       6.800000    45.000000     1.000000     1.000000     1.000000
# max       9.500000    90.000000     1.000000     1.000000     1.000000
#
#          Turbidity       Colour
# count  1059.000000  1059.000000
# mean      0.491029   251.840415
# std       0.500156     4.307424
# min       0.000000   240.000000
# 25%       0.000000   250.000000
# 50%       0.000000   255.000000
# 75%       1.000000   255.000000
# max       1.000000   255.000000

# %%
import plotly.express as px
fig = px.histogram(TrainDataSet, 
                   x='Grade',
                   color = 'Grade',
                   text_auto=True,
                   color_discrete_sequence=px.colors.qualitative.G10,
                   template='simple_white',
                   labels={"Grade": "Grade"},
                   title='Grade Value Count')

fig.update_layout(bargap=0.1, xaxis_title="Grade",yaxis_title="Quantity")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="37d71186-484f-4f50-92a8-4aedf1876566" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37d71186-484f-4f50-92a8-4aedf1876566")) {                    Plotly.newPlot(                        "37d71186-484f-4f50-92a8-4aedf1876566",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Grade=%{x}<br>count=%{y}<extra></extra>","legendgroup":"high","marker":{"color":"#3366CC","pattern":{"shape":""}},"name":"high","offsetgroup":"high","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high","high"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Grade=%{x}<br>count=%{y}<extra></extra>","legendgroup":"low","marker":{"color":"#DC3912","pattern":{"shape":""}},"name":"low","offsetgroup":"low","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low","low" ...

# %% [markdown]
# DATA CLEANING

# %%
input_cols = TrainDataSet.columns[:-1]
input_cols
# Out:
# Index(['pH', 'Temprature', 'Taste', 'Odor', 'Fat ', 'Turbidity', 'Colour'], dtype='object')

# %%
target_col =  TrainDataSet.columns[-1]
target_col
# Out:
# 'Grade'

# %%
inputs_df = TrainDataSet[list(input_cols)].copy()
inputs_df
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour
# 0     6.6          35      1     0     1          0     254
# 1     6.6          36      0     1     0          1     253
# 2     8.5          70      1     1     1          1     246
# 3     9.5          34      1     1     0          1     255
# 4     6.6          37      0     0     0          0     255
# ...   ...         ...    ...   ...   ...        ...     ...
# 1054  6.7          45      1     1     0          0     247
# 1055  6.7          38      1     0     1          0     255
# 1056  3.0          40      1     1     1          1     255
# 1057  6.8          43      1     0     1          0     250
# 1058  8.6          55      0     1     1          1     255
#
# [1059 rows x 7 columns]

# %%
targets = TrainDataSet[(target_col)]
targets
# Out:
# 0         high
# 1         high
# 2          low
# 3          low
# 4       medium
#          ...
# 1054    medium
# 1055      high
# 1056       low
# 1057      high
# 1058       low
# Name: Grade, Length: 1059, dtype: object

# %% [markdown]
# AUTOML MODEL

# %%
import tensorflow as tf
import os
from sklearn.datasets import load_files
import autokeras as ak

# %%
#separo datps de las etiquetas de los resultados


x = inputs_df

y = np.array(targets)


#separo datos en trainig y test
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size = 0.2)

x_train = np.array(X_train)
y_train = np.array(y_train)
x_test = np.array(X_test)
y_test = np.array(y_test)



print(x_train,y_train)
# Out:
# [[  6.8  40.    1.  ...   1.    0.  245. ]
#  [  6.8  34.    0.  ...   0.    1.  240. ]
#  [  9.   43.    1.  ...   1.    1.  250. ]
#  ...
#  [  9.5  34.    1.  ...   0.    1.  255. ]
#  [  6.8  36.    0.  ...   1.    0.  253. ]
#  [  9.   43.    1.  ...   1.    1.  248. ]] ['medium' 'medium' 'low' 'low' 'medium' 'low' 'low' 'medium' 'low'
#  'medium' 'medium' 'medium' 'high' 'high' 'medium' 'high' 'low' 'medium'
#  'low' 'high' 'medium' 'low' 'medium' 'low' 'high' 'low' 'medium' 'medium'
#  'high' 'medium' 'medium' 'low' 'medium' 'low' 'high' 'high' 'low' 'low'
#  'low' 'medium' 'medium' 'medium' 'low' 'high' 'low' 'high' 'low' 'low'
#  'medium' 'low' 'medium' 'low' 'low' 'medium' 'medium' 'medium' 'low'
#  'low' 'low' 'high' 'medium' 'low' 'low' 'low' 'medium' 'high' 'low' 'low'
#  'high' 'medium' 'medium' 'medium' 'low' 'medium' 'low' 'low' 'medium'
#  'high' 'medium' 'low' 'high' 'medium' 'medium' 'high' 'high' 'high' 'low'
#  'high' 'low' 'high' 'low' 'low' 'medium' 'medium' 'low' 'medium' 'high'
#  'low' 'medium' 'low' 'medium' 'low' 'medium' 'medium' 'medium' 'high'
#  'low' 'medium' 'low' 'low' 'medium' 'high' 'high' 'medium' 'low' 'low'
#  'high' 'medium' 'high' 'low' 'low' 'medium' 'medium' 'medium' 'low' 'low'
#  'medium' 'low' 'low' 'high' 'medium' 'low' 'low' 'low' 'medium' 'medium'
#  'medium' 'high' 'high' 'low' 'medium' 'medium' 'low' 'low' 'low' 'high'
#  'high' 'low' 'high' 'medium' 'medium' 'high' 'medium' 'low' 'low' 'high'
#  'medium' 'high' 'high' 'high' 'low' 'medium' 'low' 'high' 'high' 'medium'
#  'high' 'high' 'low' 'medium' 'medium' 'low' 'high' 'medium' 'medium'
#  'medium' 'low' 'low' 'high' 'medium' 'medium' 'low' 'medium' 'medium'
#  'low' 'high' 'high' 'low' 'low' 'high' 'medium' 'medium' 'medium'
#  'medium' 'high' 'low' 'low' 'low' 'medium' 'medium' 'medium' 'medium'
#  'low' 'high' 'high' 'medium' 'high' 'low' 'medium' 'medium' 'low' 'low'
#  'low' 'medium' 'low' 'low' 'low' 'low' 'medium' 'low' 'low' 'medium'
#  'medium' 'medium' 'high' 'medium' 'high' 'low' 'low' 'medium' 'medium'
#  'high' 'low' 'low' 'high' 'medium' 'low' 'low' 'medium' 'high' 'low'
#  'medium' 'high' 'low' 'high' 'low' 'medium' 'high' 'medium' 'low' 'high'
#  'low' 'high' 'low' 'low' 'medium' 'low' 'high' 'low' 'low' 'medium' 'low'
#  'medium' 'high' 'medium' 'high' 'low' 'medium' 'medium' 'medium' 'low'
#  'medium' 'medium' 'low' 'high' 'medium' 'medium' 'high' 'high' 'medium'
#  'high' 'low' 'low' 'high' 'low' 'low' 'medium' 'high' 'high' 'low'
#  'medium' 'medium' 'low' 'low' 'high' 'low' 'medium' 'medium' 'low' 'low'
#  'low' 'high' 'medium' 'high' 'low' 'low' 'low' 'high' 'low' 'medium'
#  'medium' 'high' 'medium' 'medium' 'low' 'medium' 'medium' 'high' 'low'
#  'high' 'low' 'low' 'low' 'low' 'medium' 'medium' 'medium' 'medium'
#  'medium' 'low' 'low' 'low' 'low' 'high' 'high' 'medium' 'low' 'high'
#  'medium' 'low' 'high' 'high' 'low' 'medium' 'medium' 'medium' 'medium'
#  'low' 'high' 'high' 'medium' 'low' 'medium' 'medium' 'high' 'medium'
#  'medium' 'medium' 'low' 'high' 'medium' 'medium' 'low' 'low' 'medium'
#  'medium' 'high' 'low' 'medium' 'medium' 'medium' 'medium' 'medium' 'low'
#  'medium' 'low' 'high' 'low' 'high' 'medium' 'medium' 'low' 'high'
#  'medium' 'low' 'medium' 'low' 'high' 'medium' 'medium' 'high' 'low' 'low'
#  'low' 'high' 'low' 'medium' 'medium' 'medium' 'medium' 'low' 'low' 'low'
#  'medium' 'medium' 'high' 'high' 'medium' 'low' 'medium' 'low' 'low'
#  'high' 'low' 'low' 'low' 'high' 'medium' 'low' 'low' 'medium' 'low' 'low'
#  'high' 'low' 'medium' 'medium' 'medium' 'high' 'low' 'medium' 'medium'
#  'low' 'medium' 'medium' 'medium' 'low' 'medium' 'low' 'medium' 'low'
#  'low' 'low' 'low' 'high' 'medium' 'low' 'medium' 'medium' 'low' 'high'
#  'high' 'medium' 'medium' 'medium' 'high' 'medium' 'high' 'medium'
#  'medium' 'low' 'medium' 'high' 'low' 'low' 'high' 'low' 'low' 'medium'
#  'medium' 'high' 'low' 'medium' 'low' 'high' 'medium' 'low' 'medium'
#  'medium' 'high' 'high' 'high' 'low' 'high' 'low' 'low' 'low' 'medium'
#  'medium' 'medium' 'medium' 'low' 'low' 'low' 'medium' 'low' 'low'
#  'medium' 'high' 'medium' 'low' 'high' 'medium' 'high' 'high' 'medium'
#  'medium' 'high' 'medium' 'high' 'medium' 'medium' 'medium' 'medium'
#  'high' 'low' 'low' 'medium' 'high' 'high' 'low' 'high' 'high' 'high'
#  'low' 'low' 'low' 'medium' 'low' 'low' 'low' 'medium' 'low' 'medium'
#  'high' 'low' 'low' 'medium' 'high' 'medium' 'low' 'low' 'high' 'medium'
#  'low' 'low' 'low' 'low' 'low' 'low' 'low' 'low' 'medium' 'low' 'medium'
#  'high' 'low' 'medium' 'medium' 'low' 'low' 'low' 'high' 'high' 'low'
#  'high' 'low' 'medium' 'low' 'medium' 'low' 'high' 'medium' 'medium' 'low'
#  'low' 'low' 'medium' 'low' 'medium' 'medium' 'low' 'medium' 'high' 'low'
#  'medium' 'low' 'low' 'low' 'high' 'high' 'high' 'low' 'low' 'high' 'low'
#  'low' 'low' 'medium' 'low' 'medium' 'low' 'high' 'high' 'high' 'low'
#  'medium' 'medium' 'low' 'high' 'high' 'medium' 'high' 'low' 'low' 'low'
#  'low' 'low' 'low' 'low' 'low' 'low' 'low' 'low' 'medium' 'low' 'medium'
#  'low' 'high' 'medium' 'low' 'medium' 'low' 'high' 'medium' 'medium'
#  'high' 'low' 'low' 'medium' 'low' 'high' 'low' 'low' 'low' 'low' 'low'
#  'high' 'low' 'medium' 'medium' 'medium' 'medium' 'high' 'high' 'low'
#  'low' 'high' 'high' 'medium' 'low' 'medium' 'high' 'low' 'medium'
#  'medium' 'high' 'low' 'low' 'low' 'low' 'medium' 'low' 'medium' 'low'
#  'low' 'low' 'low' 'high' 'low' 'low' 'low' 'medium' 'low' 'low' 'high'
#  'low' 'medium' 'medium' 'low' 'high' 'low' 'low' 'medium' 'medium' 'low'
#  'low' 'low' 'high' 'low' 'medium' 'medium' 'high' 'high' 'low' 'low'
#  'high' 'high' 'medium' 'medium' 'medium' 'medium' 'high' 'medium'
#  'medium' 'medium' 'high' 'low' 'medium' 'medium' 'low' 'high' 'low'
#  'high' 'low' 'low' 'medium' 'medium' 'medium' 'low' 'medium' 'high' 'low'
#  'low' 'low' 'low' 'medium' 'low' 'medium' 'high' 'medium' 'medium' 'high'
#  'high' 'high' 'low' 'high' 'medium' 'low' 'medium' 'high' 'low' 'medium'
#  'low' 'high' 'medium' 'medium' 'low' 'medium' 'high' 'low' 'medium'
#  'medium' 'medium' 'low' 'medium' 'low' 'medium' 'medium' 'medium'
#  'medium' 'medium' 'high' 'high' 'low' 'high' 'medium' 'low' 'low' 'high'
#  'high' 'low' 'low' 'high' 'medium' 'low' 'high' 'low' 'low' 'low' 'low'
#  'low' 'medium' 'high' 'high' 'low' 'medium' 'low' 'medium' 'medium'
#  'high' 'high' 'medium' 'medium' 'medium' 'high' 'high' 'high' 'low' 'low'
#  'medium' 'high' 'low' 'high' 'medium' 'low' 'high' 'low' 'medium' 'low'
#  'low' 'high' 'medium' 'low' 'low' 'low' 'medium' 'high' 'high' 'medium'
#  'low' 'medium' 'high' 'low' 'high' 'medium' 'low' 'medium' 'medium' 'low'
#  'low' 'low' 'low' 'medium' 'low' 'high' 'low']

# %%
print(x_train.shape)  # (60000, 28, 28)
print(y_train.shape)  # (60000,)
print(y_train[:3])
# Out:
# (847, 7)
# (847,)
# ['medium' 'medium' 'low']

# %%
# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    overwrite=True, max_trials=3
)  # It tries 3 different models.
# Feed the structured data classifier with training data.
history = clf.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Predict with the best model.
predicted_y = clf.predict(x_test)
print(predicted_y)
# Evaluate the best model with testing data.
print(clf.evaluate(x_test, y_test))
# Out:
# Trial 3 Complete [00h 00m 06s]
# val_accuracy: 0.8915094137191772
#
# Best val_accuracy So Far: 0.9386792182922363
# Total elapsed time: 00h 00m 20s
# Epoch 1/10
# 27/27 [==============================] - 1s 12ms/step - loss: 0.9018 - accuracy: 0.5950 - val_loss: 0.7794 - val_accuracy: 0.6132
# Epoch 2/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.6777 - val_loss: 0.6286 - val_accuracy: 0.6557
# Epoch 3/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5590 - accuracy: 0.7686 - val_loss: 0.5218 - val_accuracy: 0.8443
# Epoch 4/10
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4685 - accuracy: 0.8571 - val_loss: 0.4318 - val_accuracy: 0.8774
# Epoch 5/10
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3959 - accuracy: 0.8890 - val_loss: 0.3532 - val_accuracy: 0.9057
# Epoch 6/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3359 - accuracy: 0.8973 - val_loss: 0.2906 - val_accuracy: 0.9340
# Epoch 7/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2892 - accuracy: 0.9044 - val_loss: 0.2445 - val_accuracy: 0.9245
# Epoch 8/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2540 - accuracy: 0.9126 - val_loss: 0.2097 - val_accuracy: 0.9292
# Epoch 9/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2261 - accuracy: 0.9221 - val_loss: 0.1838 - val_accuracy: 0.9481
# Epoch 10/10
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2040 - accuracy: 0.9504 - val_loss: 0.1634 - val_accuracy: 0.9764
# 7/7 [==============================] - 0s 3ms/step
# [['medium']
#  ['medium']
#  ['high']
#  ['low']
#  ['high']
#  ['low']
#  ['high']
#  ['medium']
#  ['high']
#  ['low']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['high']
#  ['low']
#  ['high']
#  ['high']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['high']
#  ['high']
#  ['high']
#  ['low']
#  ['low']
#  ['high']
#  ['high']
#  ['high']
#  ['low']
#  ['high']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['high']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['medium']
#  ['high']
#  ['low']
#  ['high']
#  ['low']
#  ['low']
#  ['high']
#  ['medium']
#  ['low']
#  ['low']
#  ['low']
#  ['low']
#  ['high']
#  ['low']
#  ['low']
#  ['medium']
#  ['high']
#  ['medium']
#  ['medium']
#  ['low']
#  ['medium']
#  ['low']
#  ['high']
#  ['high']
#  ['high']
#  ['low']
#  ['high']
#  ['low']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['low']
#  ['low']
#  ['low']
#  ['medium']
#  ['low']
#  ['medium']
#  ['low']
#  ['medium']
#  ['medium']
#  ['low']
#  ['medium']
#  ['high']
#  ['low']
#  ['high']
#  ['high']
#  ['high']
#  ['high']
#  ['low']
#  ['medium']
#  ['medium']
#  ['high']
#  ['high']
#  ['low']
#  ['low']
#  ['low']
#  ['high']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['low']
#  ['low']
#  ['low']
#  ['medium']
#  ['low']
#  ['low']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['high']
#  ['medium']
#  ['high']
#  ['low']
#  ['low']
#  ['high']
#  ['medium']
#  ['high']
#  ['high']
#  ['medium']
#  ['high']
#  ['low']
#  ['low']
#  ['medium']
#  ['low']
#  ['low']
#  ['high']
#  ['high']
#  ['low']
#  ['low']
#  ['low']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['low']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['low']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['low']
#  ['high']
#  ['medium']
#  ['low']
#  ['high']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['high']
#  ['medium']
#  ['medium']
#  ['high']
#  ['high']
#  ['low']
#  ['low']
#  ['high']
#  ['low']
#  ['medium']
#  ['low']
#  ['medium']
#  ['high']
#  ['low']
#  ['medium']
#  ['high']
#  ['low']
#  ['low']
#  ['medium']
#  ['low']
#  ['medium']
#  ['low']
#  ['high']
#  ['low']
#  ['medium']
#  ['low']
#  ['high']
#  ['high']
#  ['low']
#  ['low']
#  ['high']
#  ['high']
#  ['low']
#  ['medium']
#  ['medium']
#  ['medium']
#  ['low']
#  ['low']
#  ['medium']
#  ['low']
#  ['medium']
#  ['high']
#  ['low']
#  ['medium']
#  ['medium']
#  ['high']
#  ['low']
#  ['high']
#  ['medium']
#  ['low']
#  ['low']]
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9764
# [0.1634303629398346, 0.9764150977134705]

# %% [markdown]
# evaluar red

# %%
res = clf.evaluate(x_test,y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9764

# %% [markdown]
# Predecir nuevos resultados

# %%
y_pred = clf.predict(x_test)

for i in range(50):
  print("valor real: ", y_test[i])
  print("valor estimado: ", y_pred[i])
  print("---------------------------------- ")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  low
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  low
# valor estimado:  ['low']
# ----------------------------------
# valor real:  high
# valor estimado:  ['high']
# ----------------------------------
# valor real:  medium
# valor estimado:  ['medium']
# ----------------------------------

# %% [markdown]
# Curva de aprendizaje

# %%
from matplotlib import pyplot
f, ax = pyplot.subplots()
ax.set_ylim(bottom=0.5)
ax.plot(history.history['accuracy'], label='entrenamiento')
ax.plot(history.history['val_accuracy'], label='prueba')
pyplot.legend()
pyplot.show(f)
print(history.history['accuracy'])
# Out:
# [0.5950413346290588, 0.6776859760284424, 0.7685950398445129, 0.8571428656578064, 0.8890200853347778, 0.8972845077514648, 0.9043683409690857, 0.9126328229904175, 0.9220778942108154, 0.9504132270812988]
